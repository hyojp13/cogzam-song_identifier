# %%
import numpy as np

# %%
song1_fingerprints = [[(378, 437, 0),
   (378, 465, 0),
   (378, 528, 0),
   (378, 550, 0),
   (378, 595, 0),
   (378, 687, 0),
   (378, 742, 0),
   (378, 805, 0),
   (378, 843, 0),
   (378, 897, 0),
   (378, 944, 0),
   (378, 986, 0),
   (378, 1045, 0),
   (378, 1113, 0),
   (378, 1137, 0)],
  [(437, 465, 0),
   (437, 528, 0),
   (437, 550, 0),
   (437, 595, 0),
   (437, 687, 0),
   (437, 742, 0),
   (437, 805, 0),
   (437, 843, 0),
   (437, 897, 0),
   (437, 944, 0),
   (437, 986, 0),
   (437, 1045, 0),
   (437, 1113, 0),
   (437, 1137, 0),
   (437, 1175, 0)],
  [(465, 528, 0),
   (465, 550, 0),
   (465, 595, 0),
   (465, 687, 0),
   (465, 742, 0),
   (465, 805, 0),
   (465, 843, 0),
   (465, 897, 0),
   (465, 944, 0),
   (465, 986, 0),
   (465, 1045, 0),
   (465, 1113, 0),
   (465, 1137, 0),
   (465, 1175, 0),
   (465, 1266, 0)],
  [(528, 550, 0),
   (528, 595, 0),
   (528, 687, 0),
   (528, 742, 0),
   (528, 805, 0),
   (528, 843, 0),
   (528, 897, 0),
   (528, 944, 0),
   (528, 986, 0),
   (528, 1045, 0),
   (528, 1113, 0),
   (528, 1137, 0),
   (528, 1175, 0),
   (528, 1266, 0),
   (528, 1293, 0)],
  [(550, 595, 0),
   (550, 687, 0),
   (550, 742, 0),
   (550, 805, 0),
   (550, 843, 0),
   (550, 897, 0),
   (550, 944, 0),
   (550, 986, 0),
   (550, 1045, 0),
   (550, 1113, 0),
   (550, 1137, 0),
   (550, 1175, 0),
   (550, 1266, 0),
   (550, 1293, 0),
   (550, 1345, 0)],
  [(595, 687, 0),
   (595, 742, 0),
   (595, 805, 0),
   (595, 843, 0),
   (595, 897, 0),
   (595, 944, 0),
   (595, 986, 0),
   (595, 1045, 0),
   (595, 1113, 0),
   (595, 1137, 0),
   (595, 1175, 0),
   (595, 1266, 0),
   (595, 1293, 0),
   (595, 1345, 0),
   (595, 1371, 0)],
  [(687, 742, 0),
   (687, 805, 0),
   (687, 843, 0),
   (687, 897, 0),
   (687, 944, 0),
   (687, 986, 0),
   (687, 1045, 0),
   (687, 1113, 0),
   (687, 1137, 0),
   (687, 1175, 0),
   (687, 1266, 0),
   (687, 1293, 0),
   (687, 1345, 0),
   (687, 1371, 0),
   (687, 1415, 0)]]

song2_fingerprints = [[(979, 1381, 0), (979, 1405, 0), (979, 306, 2), (979, 1013, 2), (979, 1308, 2), (979, 1617, 2), (979, 1772, 2), (979, 1593, 3), (979, 572, 5), (979, 785, 5), (979, 1081, 5), (979, 1147, 5), (979, 330, 6), (979, 1751, 6), (979, 1031, 7)], [(1381, 1405, 0), (1381, 306, 2), (1381, 1013, 2), (1381, 1308, 2), (1381, 1617, 2), (1381, 1772, 2), (1381, 1593, 3), (1381, 572, 5), (1381, 785, 5), (1381, 1081, 5), (1381, 1147, 5), (1381, 330, 6), (1381, 1751, 6), (1381, 1031, 7), (1381, 1183, 7)], [(1405, 306, 2), (1405, 1013, 2), (1405, 1308, 2), (1405, 1617, 2), (1405, 1772, 2), (1405, 1593, 3), (1405, 572, 5), (1405, 785, 5), (1405, 1081, 5), (1405, 1147, 5), (1405, 330, 6), (1405, 1751, 6), (1405, 1031, 7), (1405, 1183, 7), (1405, 1539, 7)]]

# %%
from database import Database
import numpy as np

# %%
database = Database()

#database.load_database()
database.store_fingerprints(song1_fingerprints, "first_song", [0,0,0,0,0,0,0]) 
database.store_fingerprints(song2_fingerprints, "second_song", [0,0,0]) #time array not doing anything?

# %%
database.search_song([[(687, 742, 0),
   (687, 805, 0),
   (687, 843, 0),
   (687, 897, 0),
   (687, 944, 0),
   (687, 986, 0),
   
   (687, 1345, 0),
   (687, 1371, 0),
   (687, 1415, 0)], [(687, 742, 0),
   (687, 805, 0),
   (687, 843, 0),
   (687, 897, 0),
   (687, 944, 0),
   (687, 986, 0),

   (687, 1293, 0),
   (687, 1345, 0),
   (687, 1371, 0),
   (687, 1415, 0)]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20532/2521821474.py in <module>
# ----> 1 database.search_song([[(687, 742, 0),
#       2    (687, 805, 0),
#       3    (687, 843, 0),
#       4    (687, 897, 0),
#       5    (687, 944, 0),
#
# TypeError: search_song() missing 1 required positional argument: 'times'
